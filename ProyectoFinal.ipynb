# %% [markdown]
# <a href="https://colab.research.google.com/github/Sinnombre0/Proyecto-Final-/blob/main/ProyectoFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyecto Final
# ### Eleccion del dataset
# Para realizar el proyecto se eligio el dataset **Uso de las redes sociales de la generación Z** al que se le va a aplicar el metodo de agrupamiento no supervisado **K-means** para poder visualizar mejor cual es el grupo de entre 13 a 27 que presenta un mayor uso de redes sociales

# %%
pip install --upgrade jupyter_client

# %%
#Hacemos la carga del dataset
import kagglehub
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# Descargamos la ultima version
path = kagglehub.dataset_download("sharmajicoder/gen-z-social-media-usage-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 42.1M/42.1M [00:00<00:00, 78.3MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/sharmajicoder/gen-z-social-media-usage-dataset/versions/1

# %% [markdown]
# ## K-means
# **K-means** es un método de agrupamiento que divide un conjunto de datos en k grupos o clusteres, pertenece al universo de los algoritmo de **aprendizaje no supervisado** siendo este uno de los métodos más utilizados en el campo de la minería de datos y el machine learning para el agrupamiento de información
#
# ### Como funciona K-means?
# Primero se especifica el número de clusters deseados (k). Por ejemplo, al establecer «k» igual a 2, su conjunto de datos se agrupará en 2 grupos, mientras que si establece «k» igual a 4, agrupará los datos en 4 grupos.
#
# Cada grupo está representado por su centro o centroide, que corresponde a la media aritmética de los puntos de datos asignados al grupo. De esta manera, el algoritmo funciona a través de un proceso iterativo hasta que cada punto de datos está más cerca del centroide de su propio grupo que de los centroides de otros grupos, minimizando la distancia dentro del grupo en cada paso.

# %% [markdown]
# ## Funcionamiento paso a paso de K-means
# 1. **Especificar el número de clústers deseados (k)**: El primer paso es
# especificar cuántos clúster queremos dividir el conjunto de datos. Este número se denomina k.

# %% [markdown]
# 2. **Seleccionar k puntos al azar del conjunto de datos como los centroides iniciales de cada clúster**: Luego, se eligen k puntos al azar del conjunto de datos para servir como los centroides iniciales de cada clúster. Estos centroides son el punto central o el promedio de cada clúster.

# %% [markdown]
# 3. **Asignar cada punto del conjunto de datos al cluster cuyo centroide esté más cerca**: El algoritmo asigna cada punto del conjunto de datos al cluster cuyo centroide esté más cerca. Para hacer esto, se calcula la distancia entre cada punto y cada centroide y se asigna el punto al cluster cuyo centroide tenga la menor distancia.

# %% [markdown]
# 4. **Recalcular los centroides de cada cluster como la media de todos los puntos del cluster**: Una vez que todos los puntos han sido asignados a un cluster, se recalculan los centroides de cada cluster como la media de todos los puntos del cluster.

# %% [markdown]
# ####**Criterio de optimalidad**
# 5. **Repetir los pasos 3 y 4** hasta que los centroides de los clusters ya no cambien o hasta que se alcance el número máximo de iteraciones.

# %% [markdown]
# ## Metodo del codo
# ¿Como sabemos cual es el **K** adecuado para el numero de clusters de K-means?
#
# Cuando definimos **K** estamos estableciendo el numero de centroides pero como sabra cuantos grupos producir
#
# Por ello tenemos el metodo del codo para ayudar a responder a esto para ello se grafican los valores de **K** junto con la suma de los errores cuadrados (SSE) para cada valor de **K**. El SSE es la suma de la distancia de cada punto al centroide de su cluster. A medida que aumenta **K**, el SSE disminuye, pero a un ritmo cada vez menor. El punto en el que el SSE disminuye más lentamente se conoce como el codo y es el punto óptimo para elegir **K**.
